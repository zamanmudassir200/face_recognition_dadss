# %%
import face_recognition
import cv2
import os
import json
import sys
import pickle
# !pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\face\lib\site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.20 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\programdata\anaconda3\envs\face\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\programdata\anaconda3\envs\face\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\envs\face\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import time

def recognize_face(input_image_file):
    start_time = time.time()

    known_faces = []
    known_names = []

    # known_dir = "known_faces/"
    # for filename in os.listdir(known_dir):
    #     if filename.lower().endswith(('.jpg', '.png', '.jpeg')):
    #         image = face_recognition.load_image_file(os.path.join(known_dir, filename))
    #         encodings = face_recognition.face_encodings(image)
    #         if encodings:
    #             known_faces.append(encodings[0])
    #             known_names.append(filename.split('.')[0])
    for filename in os.listdir("known_faces"):
        image = face_recognition.load_image_file(f"known_faces/{filename}")
        enc = face_recognition.face_encodings(image)
        if enc:
            known_faces.append(enc[0])
            known_names.append(filename.split('.')[0])

    with open("encodings.pkl", "wb") as f:
         pickle.dump((known_faces, known_names), f)
    input_image = face_recognition.load_image_file(input_image_file)
    face_locations = face_recognition.face_locations(input_image, model="cnn")
    input_encodings = face_recognition.face_encodings(input_image, face_locations)

    if not input_encodings:
        return {"status": "no_face_detected"}
#     plt.plot(input_image)
    for input_encoding in input_encodings:
        results = face_recognition.compare_faces(known_faces, input_encoding)
        if True in results:
            matched_index = results.index(True)
            end_time = time.time()
            return {
                "status": "matched",
                "person": known_names[matched_index],
                "time_taken_sec": round(end_time - start_time, 3)
            }
    
    end_time = time.time()
    return {
        "status": "not_matched",
        "time_taken_sec": round(end_time - start_time, 3)
    }

# Command line usage 
if __name__ == "__main__": 
    if len(sys.argv) > 1: 
        # image_path = sys.argv[1] 
        result = recognize_face('another_man.jpg') 
        print(json.dumps(result))
    else: 
        print('Usage: python face_recognition_script.py <image_path>')
# Out:
# {"status": "not_matched", "time_taken_sec": 2.975}
